# %%
import pandas as pd
print("Setup successful!")
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/KOGBARA BURABARI/AppData/Local/Microsoft/WindowsApps/python3.13.exe" -m pip install ipykernel -U --user --force-reinstall'
